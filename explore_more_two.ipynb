# %%
import pandas as pd
from openpyxl import Workbook
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp
from matplotlib import pyplot as plt

df = pd.read_excel (r'Desktop/technical_case.xlsx', sheet_name='Data')
df
# Out:
#             Month   Website            Vertical  \
# 0      2021-01-01  98761252  consumer_equipment
# 1      2021-01-01  98761252  consumer_equipment
# 2      2021-01-01  98761252  consumer_equipment
# 3      2021-01-01  98761252  consumer_equipment
# 4      2021-01-01  98761252  consumer_equipment
# ...           ...       ...                 ...
# 259532 2021-06-01  98766809             fashion
# 259533 2021-06-01  98766809             fashion
# 259534 2021-06-01  98766809             fashion
# 259535 2021-06-01  98766809             fashion
# 259536 2021-06-01  98766809             fashion
#
#                            Sub Vertical Country   Device  Sessions  \
# 0       home_decor,office_supplies,tech      AT  Desktop       558
# 1       home_decor,office_supplies,tech      BE  Desktop     26715
# 2       home_decor,office_supplies,tech      CA  Desktop     11466
# 3       home_decor,office_supplies,tech      CH  Desktop     14941
# ...

# %%
df.describe(include =object)
# Out:
#        Vertical Sub Vertical Country   Device
# count    259537       259537  259537   259537
# unique        7           93      16        3
# top     fashion   home_decor      US  Desktop
# freq      81748        29960   18326    91598

# %%
df.head()
# Out:
#        Month   Website            Vertical                     Sub Vertical  \
# 0 2021-01-01  98761252  consumer_equipment  home_decor,office_supplies,tech
# 1 2021-01-01  98761252  consumer_equipment  home_decor,office_supplies,tech
# 2 2021-01-01  98761252  consumer_equipment  home_decor,office_supplies,tech
# 3 2021-01-01  98761252  consumer_equipment  home_decor,office_supplies,tech
# 4 2021-01-01  98761252  consumer_equipment  home_decor,office_supplies,tech
#
#   Country   Device  Sessions  New sessions  Bounce sessions  Buying sessions  \
# 0      AT  Desktop       558           399              298                5
# 1      BE  Desktop     26715         17384            13827              124
# 2      CA  Desktop     11466          9204             6814               46
# 3      CH  Desktop     14941          9941             7063              159
# 4      DE  Desktop      7102          4563             3423              111
#
#    Pageviews  Total time spent sec
# ...

# %%
df.tail()
# Out:
#             Month   Website Vertical Sub Vertical Country  Device  Sessions  \
# 259532 2021-06-01  98766809  fashion     footwear      BE  Tablet         3
# 259533 2021-06-01  98766809  fashion     footwear      CA  Tablet         2
# 259534 2021-06-01  98766809  fashion     footwear      DE  Tablet         3
# 259535 2021-06-01  98766809  fashion     footwear      FR  Tablet       334
# 259536 2021-06-01  98766809  fashion     footwear      IE  Tablet         1
#
#         New sessions  Bounce sessions  Buying sessions  Pageviews  \
# 259532             3                1                0          9
# 259533             2                0                0         17
# 259534             1                3                0          3
# 259535           300               74                0       3224
# 259536             1                0                0          5
#
#         Total time spent sec
# 259532                411.46
# 259533               1150.60
# ...

# %%
df.shape
# Out:
# (259537, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259537 entries, 0 to 259536
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Month                 259537 non-null  datetime64[ns]
#  1   Website               259537 non-null  int64
#  2   Vertical              259537 non-null  object
#  3   Sub Vertical          259537 non-null  object
#  4   Country               259537 non-null  object
#  5   Device                259537 non-null  object
#  6   Sessions              259537 non-null  int64
#  7   New sessions          259537 non-null  int64
#  8   Bounce sessions       259537 non-null  int64
#  9   Buying sessions       259537 non-null  int64
#  10  Pageviews             259537 non-null  int64
#  11  Total time spent sec  259537 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 23.8+ MB

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         Month  Website  Vertical  Sub Vertical  Country  Device  Sessions  \
# 0       False    False     False         False    False   False     False
# 1       False    False     False         False    False   False     False
# 2       False    False     False         False    False   False     False
# 3       False    False     False         False    False   False     False
# 4       False    False     False         False    False   False     False
# ...       ...      ...       ...           ...      ...     ...       ...
# 259532  False    False     False         False    False   False     False
# 259533  False    False     False         False    False   False     False
# 259534  False    False     False         False    False   False     False
# 259535  False    False     False         False    False   False     False
# 259536  False    False     False         False    False   False     False
#
# ...

# %%
df['Total time spent sec'].min()
# Out:
# 0.0

# %%
df['Total time spent sec'].max()
# Out:
# 23492899497.19

# %%
df.plot(x="Total time spent sec", y=["Bounce sessions"],
        kind="line", figsize=(10, 10))
 
# display plot
mp.show()

# %%
df.plot(x="Pageviews", y=["Buying sessions"],
        kind="line", figsize=(10, 10))
 
# display plot
mp.show()

# %%
plt.plot(df["Pageviews"]),df["Buying sessions"]
# Out:
# ([<matplotlib.lines.Line2D at 0x13e2764a0>],
#  0           5
#  1         124
#  2          46
#  3         159
#  4         111
#           ...
#  259532      0
#  259533      0
#  259534      0
#  259535      0
#  259536      0
#  Name: Buying sessions, Length: 259537, dtype: int64)

# %%
device_compare1 = pd.DataFrame(df.groupby('Device').sum()["Bounce sessions"])

# %%
device_compare1.sort_values("Bounce sessions", ascending =False)
# Out:
#          Bounce sessions
# Device
# Mobile        4595750901
# Desktop       2368904067
# Tablet         198232732
